# %%
import numpy as np
import pandas as pd
import seaborn as sns
from esda import Moran
import geopandas as gpd
import statsmodels.api as sm
import matplotlib.pyplot as plt
from libpysal.weights import KNN
from spreg import OLS, GM_Error_Het
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
gdf = gpd.read_file('output/hedonic_gdf.gpkg')

# %%
gdf['log_price'] = np.log(gdf['GrossSalePrice'])

# %%
gdf.columns
# Out:
# Index(['GrossSalePrice', 'AgeAtSale', 'LandArea', 'TotalFloorArea',
#        'water_DIST', 'bus_DIST', 'Census_Pop', 'RnkIMDNoEm', 'RnkIMDNoIn',
#        'RnkIMDNoCr', 'RnkIMDNoHo', 'RnkIMDNoHe', 'RnkIMDNoEd', 'RnkIMDNoAc',
#        'DECILE_high', 'DECILE_prim', 'Median_Income', 'CBD_DIST',
#        'cycleways_DIST', 'cycle_DENS', 'year_2018', 'year_2019', 'canopy_0_20',
#        'canopy_20_50', 'canopy_50_100', 'canopy_100_200', 'residuals',
#        'geometry', 'log_price'],
#       dtype='object')

# %%
w = KNN.from_dataframe(gdf, k=8)
w.transform = 'R'
# Out:
# /Users/rujalshrestha/Projects/chc-property-prices/venv/lib/python3.13/site-packages/libpysal/weights/distance.py:153: UserWarning: The weights matrix is not fully connected:
#  There are 11 disconnected components.
#   W.__init__(self, neighbors, id_order=ids, **kwargs)

# %%
gdf.shape
# Out:
# (12431, 29)

# %%
y = gdf['log_price'].values.reshape(-1, 1)

non_x_cols = [
  # unneccessary columns
  'GrossSalePrice', 'residuals', 'geometry', 'log_price',
  # removed columns
  "Census_Pop",
  "RnkIMDNoEm",
  "RnkIMDNoIn",
  "RnkIMDNoCr",
  "RnkIMDNoHo",
  "RnkIMDNoHe",
  "RnkIMDNoEd",
  "RnkIMDNoAc",
  "DECILE_high",
  # "DECILE_prime",
  "Median_Income"
]

x_cols = [col for col in gdf.columns if col not in non_x_cols]

print(x_cols)

X = gdf.loc[:, x_cols]

X = X.values
# Out:
# ['AgeAtSale', 'LandArea', 'TotalFloorArea', 'water_DIST', 'bus_DIST', 'DECILE_prim', 'CBD_DIST', 'cycleways_DIST', 'cycle_DENS', 'year_2018', 'year_2019', 'canopy_0_20', 'canopy_20_50', 'canopy_50_100', 'canopy_100_200']

# %%
ols_spreg = OLS(y, X, w=w, spat_diag=True, moran=True, name_y='log_price', name_x=x_cols)

print(ols_spreg.summary)
# Out:
# REGRESSION RESULTS
# ------------------
#
# SUMMARY OF OUTPUT: ORDINARY LEAST SQUARES
# -----------------------------------------
# Data set            :     unknown
# Weights matrix      :     unknown
# Dependent Variable  :   log_price                Number of Observations:       12431
# Mean dependent var  :     13.1505                Number of Variables   :          16
# S.D. dependent var  :      0.3376                Degrees of Freedom    :       12415
# R-squared           :      0.5916
# Adjusted R-squared  :      0.5911
# Sum squared residual:     578.441                F-statistic           :   1199.0515
# Sigma-square        :       0.047                Prob(F-statistic)     :           0
# S.E. of regression  :       0.216                Log likelihood        :    1427.923
# Sigma-square ML     :       0.047                Akaike info criterion :   -2823.846
# S.E of regression ML:      0.2157                Schwarz criterion     :   -2704.999
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     t-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT        12.61901         0.00980      1287.55159         0.00000
#            AgeAtSale        -0.00158         0.00007       -21.87206         0.00000
#             LandArea         0.00001         0.00000        13.58746         0.00000
#       TotalFloorArea         0.00363         0.00004       102.39955         0.00000
#           water_DIST         0.00000         0.00001         0.16703         0.86735
#             bus_DIST         0.00008         0.00001         8.00440         0.00000
#          DECILE_prim         0.00162         0.00014        11.61442         0.00000
#             CBD_DIST        -0.00002         0.00000       -14.28533         0.00000
#       cycleways_DIST        -0.00003         0.00000       -11.70236         0.00000
#           cycle_DENS         0.00006         0.00001         7.61471         0.00000
#            year_2018         0.00420         0.00480         0.87540         0.38137
#            year_2019         0.02209         0.00482         4.58319         0.00000
#          canopy_0_20         0.00013         0.00002         5.82779         0.00000
#         canopy_20_50         0.00004         0.00001         7.32104         0.00000
#        canopy_50_100         0.00000         0.00000         4.71999         0.00000
#       canopy_100_200         0.00000         0.00000        10.94066         0.00000
# ------------------------------------------------------------------------------------
#
# REGRESSION DIAGNOSTICS
# MULTICOLLINEARITY CONDITION NUMBER          16.916
#
# TEST ON NORMALITY OF ERRORS
# TEST                             DF        VALUE           PROB
# Jarque-Bera                       2     122299.365           0.0000
#
# DIAGNOSTICS FOR HETEROSKEDASTICITY
# RANDOM COEFFICIENTS
# TEST                             DF        VALUE           PROB
# Breusch-Pagan test               15      30405.528           0.0000
# Koenker-Bassett test             15       3503.756           0.0000
#
# DIAGNOSTICS FOR SPATIAL DEPENDENCE
# - SARERR -
# TEST                           MI/DF       VALUE           PROB
# Moran's I (error)              0.4441      104.778           0.0000
# Lagrange Multiplier (lag)         1       8205.880           0.0000
# Robust LM (lag)                   1       1074.807           0.0000
# Lagrange Multiplier (error)       1      10876.051           0.0000
# Robust LM (error)                 1       3744.978           0.0000
# Lagrange Multiplier (SARMA)       2      11950.858           0.0000
#
# - Spatial Durbin -
# TEST                              DF       VALUE           PROB
# LM test for WX                   15       1215.214           0.0000
# Robust LM WX test                15       3885.385           0.0000
# Lagrange Multiplier (lag)         1       8205.880           0.0000
# Robust LM Lag - SDM               1      10876.051           0.0000
# Joint test for SDM               16      12091.264           0.0000
# ================================ END OF REPORT =====================================

# %% [markdown]
# # VIF

# %%
x_cols
# Out:
# ['AgeAtSale',
#  'LandArea',
#  'TotalFloorArea',
#  'water_DIST',
#  'bus_DIST',
#  'DECILE_prim',
#  'CBD_DIST',
#  'cycleways_DIST',
#  'cycle_DENS',
#  'year_2018',
#  'year_2019',
#  'canopy_0_20',
#  'canopy_20_50',
#  'canopy_50_100',
#  'canopy_100_200']

# %%
X = gdf.loc[:, x_cols]

# %%
X.head()
# Out:
#    AgeAtSale  LandArea  TotalFloorArea  water_DIST    bus_DIST  DECILE_prim  \
# 0         24     685.0           211.0  189.601703  216.798910         10.0
# 1         42     609.0           120.0  139.581200  154.824709         10.0
# 2         22     704.0           245.0  201.942495  192.941029         10.0
# 3         44     869.0           131.0  157.854014  179.645498         10.0
# 4         22    1149.0           279.0  199.693219  216.730600         10.0
#
#       CBD_DIST  cycleways_DIST  cycle_DENS  year_2018  year_2019  canopy_0_20  \
# 0  6354.291389      590.000000         1.6          0          1     1.077267
# 1  6227.397408      471.071045         1.6          0          0    20.957896
# 2  6352.891850      610.836121         1.6          1          0    10.299413
# 3  6229.065719      483.016235         1.6          0          1    74.306779
# 4  6258.811869      533.936462         1.6          1          0     0.000000
#
#    canopy_20_50  canopy_50_100  canopy_100_200
# 0    163.500474    3673.623939    10193.360430
# 1    450.415001    3568.941048    19805.408025
# 2    144.270775    2970.792200     9872.392485
# 3    392.823676    3602.928325    19098.845813
# 4    279.813206    6163.843751    14113.518330

# %%
vif_df = pd.DataFrame({
  'variable': X.columns,
  'VIF': [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
})

print(vif_df)
# Out:
#           variable       VIF
# 0        AgeAtSale  3.521190
# 1         LandArea  1.191485
# 2   TotalFloorArea  6.101419
# 3       water_DIST  2.520637
# 4         bus_DIST  2.786214
# 5      DECILE_prim  1.517704
# 6         CBD_DIST  6.092187
# 7   cycleways_DIST  3.855113
# 8       cycle_DENS  2.003174
# 9        year_2018  1.962587
# 10       year_2019  1.954268
# 11     canopy_0_20  2.985803
# 12    canopy_20_50  5.605742
# 13   canopy_50_100  2.576599
# 14  canopy_100_200  3.625759

# %% [markdown]
# # training GM_Error_Het heteroskedasticity-robust estimation

# %%
X = X.values

# %%
sem = GM_Error_Het(y, X, w, name_y = 'log_price', name_x = x_cols)

# %%
print(sem.summary)
# Out:
# REGRESSION RESULTS
# ------------------
#
# SUMMARY OF OUTPUT: GM SPATIALLY WEIGHTED LEAST SQUARES (HET)
# ------------------------------------------------------------
# Data set            :     unknown
# Weights matrix      :     unknown
# Dependent Variable  :   log_price                Number of Observations:       12431
# Mean dependent var  :     13.1505                Number of Variables   :          16
# S.D. dependent var  :      0.3376                Degrees of Freedom    :       12415
# Pseudo R-squared    :      0.5846
# N. of iterations    :           1                Step1c computed       :          No
#
# ------------------------------------------------------------------------------------
#             Variable     Coefficient       Std.Error     z-Statistic     Probability
# ------------------------------------------------------------------------------------
#             CONSTANT        12.79131         0.03012       424.73841         0.00000
#            AgeAtSale        -0.00174         0.00012       -14.72625         0.00000
#             LandArea         0.00001         0.00000         4.58942         0.00000
#       TotalFloorArea         0.00269         0.00016        17.11583         0.00000
#           water_DIST        -0.00003         0.00002        -1.34698         0.17799
#             bus_DIST         0.00010         0.00003         3.91341         0.00009
#          DECILE_prim         0.00134         0.00024         5.55514         0.00000
#             CBD_DIST        -0.00001         0.00000        -4.79110         0.00000
#       cycleways_DIST        -0.00003         0.00001        -3.63646         0.00028
#           cycle_DENS         0.00006         0.00002         2.66569         0.00768
#            year_2018         0.00071         0.00366         0.19305         0.84692
#            year_2019         0.01783         0.00356         5.01478         0.00000
#          canopy_0_20         0.00011         0.00002         5.40247         0.00000
#         canopy_20_50         0.00002         0.00001         3.47156         0.00052
#        canopy_50_100         0.00000         0.00000         3.33216         0.00086
#       canopy_100_200         0.00000         0.00000         5.18281         0.00000
#               lambda         0.72970         0.01148        63.54181         0.00000
# ------------------------------------------------------------------------------------
# ================================ END OF REPORT =====================================

# %%
gdf["e_sem"] = sem.e_filtered.flatten()  # or sem.e_filtered if already 1D
mi_sem = Moran(gdf["e_sem"], w)
print(mi_sem.I, mi_sem.p_sim)
# Out:
# -0.018002164938573557 0.001
